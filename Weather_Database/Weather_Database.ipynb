# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Import the requests library.
import requests

# Import the API key.
from config import api_key

# %%
# # Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
            # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | akhalgori
# Processing Record 2 of Set 1 | bjornevatn
# Processing Record 3 of Set 1 | victoria
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | esperance
# Processing Record 9 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 10 of Set 1 | solnechnyy
# Processing Record 11 of Set 1 | torbay
# Processing Record 12 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | pevek
# Processing Record 15 of Set 1 | constitucion
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | vardo
# Processing Record 21 of Set 1 | sistranda
# Processing Record 22 of Set 1 | hualmay
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | cherskiy
# Processing Record 25 of Set 1 | souillac
# Processing Record 26 of Set 1 | mar del plata
# Processing Record 27 of Set 1 | iqaluit
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | upernavik
# Processing Record 30 of Set 1 | kruisfontein
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | quatre cocos
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | beysehir
# Processing Record 35 of Set 1 | dobryanka
# Processing Record 36 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | smoky lake
# Processing Record 38 of Set 1 | khatanga
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 1 | saldanha
# Processing Record 42 of Set 1 | port elizabeth
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | marawi
# Processing Record 45 of Set 1 | provideniya
# Processing Record 46 of Set 1 | nouadhibou
# Processing Record 47 of Set 1 | lao cai
# Processing Record 48 of Set 1 | anaco
# Processing Record 49 of Set 1 | lompoc
# Processing Record 50 of Set 1 | hofn
# Processing Record 1 of Set 2 | nhulunbuy
# Processing Record 2 of Set 2 | geraldton
# Processing Record 3 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 2 | tiksi
# Processing Record 5 of Set 2 | kaitangata
# Processing Record 6 of Set 2 | samarai
# Processing Record 7 of Set 2 | awbari
# Processing Record 8 of Set 2 | carauari
# Processing Record 9 of Set 2 | semirom
# Processing Record 10 of Set 2 | nemuro
# Processing Record 11 of Set 2 | high level
# Processing Record 12 of Set 2 | codrington
# Processing Record 13 of Set 2 | poya
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 2 | kapaa
# Processing Record 17 of Set 2 | ahipara
# Processing Record 18 of Set 2 | georgetown
# Processing Record 19 of Set 2 | wewak
# Processing Record 20 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 2 | hambantota
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | maarianhamina
# Processing Record 24 of Set 2 | beringovskiy
# Processing Record 25 of Set 2 | rabaul
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | nishihara
# Processing Record 28 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 2 | ushuaia
# Processing Record 30 of Set 2 | thompson
# Processing Record 31 of Set 2 | los llanos de aridane
# Processing Record 32 of Set 2 | bluff
# Processing Record 33 of Set 2 | lavrentiya
# Processing Record 34 of Set 2 | cap malheureux
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | tecoanapa
# Processing Record 37 of Set 2 | kawana waters
# City not found. Skipping...
# Processing Record 38 of Set 2 | vao
# Processing Record 39 of Set 2 | vagay
# Processing Record 40 of Set 2 | coquimbo
# Processing Record 41 of Set 2 | husavik
# Processing Record 42 of Set 2 | cedar city
# Processing Record 43 of Set 2 | srednekolymsk
# Processing Record 44 of Set 2 | tura
# Processing Record 45 of Set 2 | genhe
# Processing Record 46 of Set 2 | teluknaga
# Processing Record 47 of Set 2 | mareeba
# Processing Record 48 of Set 2 | bilma
# Processing Record 49 of Set 2 | port moresby
# Processing Record 50 of Set 2 | caravelas
# Processing Record 1 of Set 3 | chuy
# Processing Record 2 of Set 3 | faanui
# Processing Record 3 of Set 3 | yellowknife
# Processing Record 4 of Set 3 | ulladulla
# Processing Record 5 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 3 | yuanping
# Processing Record 7 of Set 3 | kodiak
# Processing Record 8 of Set 3 | albany
# Processing Record 9 of Set 3 | butaritari
# Processing Record 10 of Set 3 | hilo
# Processing Record 11 of Set 3 | zabid
# Processing Record 12 of Set 3 | susanville
# Processing Record 13 of Set 3 | pacific grove
# Processing Record 14 of Set 3 | sitka
# Processing Record 15 of Set 3 | saskylakh
# Processing Record 16 of Set 3 | chokurdakh
# Processing Record 17 of Set 3 | itarema
# Processing Record 18 of Set 3 | miri
# Processing Record 19 of Set 3 | damghan
# Processing Record 20 of Set 3 | nome
# Processing Record 21 of Set 3 | malanje
# Processing Record 22 of Set 3 | cabo san lucas
# Processing Record 23 of Set 3 | belaya gora
# Processing Record 24 of Set 3 | snezhnogorsk
# Processing Record 25 of Set 3 | yeniseysk
# Processing Record 26 of Set 3 | vaini
# Processing Record 27 of Set 3 | tubigon
# Processing Record 28 of Set 3 | beloha
# Processing Record 29 of Set 3 | heihe
# Processing Record 30 of Set 3 | grand gaube
# Processing Record 31 of Set 3 | balkhash
# Processing Record 32 of Set 3 | tasiilaq
# Processing Record 33 of Set 3 | capaci
# Processing Record 34 of Set 3 | ningan
# City not found. Skipping...
# Processing Record 35 of Set 3 | pangai
# Processing Record 36 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 3 | ushtobe
# Processing Record 38 of Set 3 | moose factory
# Processing Record 39 of Set 3 | trat
# Processing Record 40 of Set 3 | bethel
# Processing Record 41 of Set 3 | bonavista
# Processing Record 42 of Set 3 | saint george
# Processing Record 43 of Set 3 | doctor arroyo
# Processing Record 44 of Set 3 | teguise
# Processing Record 45 of Set 3 | atambua
# Processing Record 46 of Set 3 | frolovo
# Processing Record 47 of Set 3 | manggar
# Processing Record 48 of Set 3 | lebu
# Processing Record 49 of Set 3 | reconquista
# Processing Record 50 of Set 3 | ribeira grande
# Processing Record 1 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 4 | grindavik
# Processing Record 3 of Set 4 | snyder
# Processing Record 4 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 4 | vila velha
# Processing Record 6 of Set 4 | avarua
# Processing Record 7 of Set 4 | clyde river
# Processing Record 8 of Set 4 | acapulco
# Processing Record 9 of Set 4 | deputatskiy
# Processing Record 10 of Set 4 | hasaki
# Processing Record 11 of Set 4 | hithadhoo
# Processing Record 12 of Set 4 | kavaratti
# Processing Record 13 of Set 4 | khasan
# Processing Record 14 of Set 4 | hobyo
# Processing Record 15 of Set 4 | new norfolk
# Processing Record 16 of Set 4 | lexington
# Processing Record 17 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 4 | luderitz
# Processing Record 19 of Set 4 | baykalovo
# Processing Record 20 of Set 4 | cartagena
# Processing Record 21 of Set 4 | rocha
# Processing Record 22 of Set 4 | amuntai
# Processing Record 23 of Set 4 | fortuna
# Processing Record 24 of Set 4 | japura
# Processing Record 25 of Set 4 | hay river
# Processing Record 26 of Set 4 | jawhar
# Processing Record 27 of Set 4 | azua
# Processing Record 28 of Set 4 | minot
# Processing Record 29 of Set 4 | kyra
# Processing Record 30 of Set 4 | faya
# Processing Record 31 of Set 4 | ponta do sol
# Processing Record 32 of Set 4 | san patricio
# Processing Record 33 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 4 | ajaccio
# Processing Record 35 of Set 4 | imeni poliny osipenko
# Processing Record 36 of Set 4 | shnogh
# Processing Record 37 of Set 4 | airai
# Processing Record 38 of Set 4 | polunochnoye
# Processing Record 39 of Set 4 | warman
# Processing Record 40 of Set 4 | barrow
# Processing Record 41 of Set 4 | norman wells
# Processing Record 42 of Set 4 | milingimbi
# City not found. Skipping...
# Processing Record 43 of Set 4 | tucupita
# Processing Record 44 of Set 4 | chiredzi
# Processing Record 45 of Set 4 | mathathane
# Processing Record 46 of Set 4 | east london
# Processing Record 47 of Set 4 | brownwood
# Processing Record 48 of Set 4 | charters towers
# Processing Record 49 of Set 4 | berbera
# Processing Record 50 of Set 4 | lagoa
# Processing Record 1 of Set 5 | byron bay
# Processing Record 2 of Set 5 | harper
# Processing Record 3 of Set 5 | teluk nibung
# Processing Record 4 of Set 5 | tselinnoye
# Processing Record 5 of Set 5 | sao filipe
# Processing Record 6 of Set 5 | fairbanks
# Processing Record 7 of Set 5 | ancud
# Processing Record 8 of Set 5 | saint-pierre
# Processing Record 9 of Set 5 | am timan
# Processing Record 10 of Set 5 | castro
# Processing Record 11 of Set 5 | vallenar
# Processing Record 12 of Set 5 | longyearbyen
# Processing Record 13 of Set 5 | urucara
# Processing Record 14 of Set 5 | dingle
# Processing Record 15 of Set 5 | zlitan
# Processing Record 16 of Set 5 | teguldet
# Processing Record 17 of Set 5 | chamba
# Processing Record 18 of Set 5 | baiyin
# Processing Record 19 of Set 5 | bataipora
# Processing Record 20 of Set 5 | alofi
# Processing Record 21 of Set 5 | sahuaripa
# Processing Record 22 of Set 5 | yumen
# Processing Record 23 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 5 | flagstaff
# Processing Record 25 of Set 5 | rio gallegos
# Processing Record 26 of Set 5 | hinckley
# Processing Record 27 of Set 5 | port blair
# Processing Record 28 of Set 5 | kisangani
# Processing Record 29 of Set 5 | sakaiminato
# Processing Record 30 of Set 5 | pisco
# Processing Record 31 of Set 5 | alyangula
# Processing Record 32 of Set 5 | berlevag
# Processing Record 33 of Set 5 | mizpe ramon
# City not found. Skipping...
# Processing Record 34 of Set 5 | sept-iles
# Processing Record 35 of Set 5 | port lincoln
# Processing Record 36 of Set 5 | puerto ayora
# Processing Record 37 of Set 5 | moengo
# Processing Record 38 of Set 5 | ranong
# Processing Record 39 of Set 5 | the pas
# Processing Record 40 of Set 5 | mingaora
# Processing Record 41 of Set 5 | sinnamary
# City not found. Skipping...
# Processing Record 42 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 5 | oktyabrskiy
# Processing Record 44 of Set 5 | dandong
# Processing Record 45 of Set 5 | saryozek
# Processing Record 46 of Set 5 | huallanca
# Processing Record 47 of Set 5 | morondava
# Processing Record 48 of Set 5 | vitim
# Processing Record 49 of Set 5 | cabedelo
# Processing Record 50 of Set 5 | dum duma
# Processing Record 1 of Set 6 | fare
# Processing Record 2 of Set 6 | ploemeur
# Processing Record 3 of Set 6 | richards bay
# Processing Record 4 of Set 6 | padang
# Processing Record 5 of Set 6 | taoudenni
# Processing Record 6 of Set 6 | lata
# Processing Record 7 of Set 6 | ayan
# Processing Record 8 of Set 6 | odweyne
# Processing Record 9 of Set 6 | nikolskoye
# Processing Record 10 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 6 | beyneu
# Processing Record 12 of Set 6 | buon me thuot
# City not found. Skipping...
# Processing Record 13 of Set 6 | el alto
# Processing Record 14 of Set 6 | metapan
# Processing Record 15 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 6 | velsk
# Processing Record 17 of Set 6 | poselki
# Processing Record 18 of Set 6 | skjervoy
# Processing Record 19 of Set 6 | kopavogur
# Processing Record 20 of Set 6 | shipitsyno
# Processing Record 21 of Set 6 | izhma
# Processing Record 22 of Set 6 | beidao
# Processing Record 23 of Set 6 | bandarbeyla
# Processing Record 24 of Set 6 | eyl
# Processing Record 25 of Set 6 | makat
# Processing Record 26 of Set 6 | tual
# Processing Record 27 of Set 6 | felipe carrillo puerto
# Processing Record 28 of Set 6 | navashino
# Processing Record 29 of Set 6 | astoria
# Processing Record 30 of Set 6 | tres arroyos
# Processing Record 31 of Set 6 | luanda
# Processing Record 32 of Set 6 | port hardy
# Processing Record 33 of Set 6 | dikson
# Processing Record 34 of Set 6 | katsuura
# Processing Record 35 of Set 6 | kiama
# Processing Record 36 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 37 of Set 6 | izvestkovyy
# Processing Record 38 of Set 6 | lazaro cardenas
# Processing Record 39 of Set 6 | nuzvid
# Processing Record 40 of Set 6 | vernon
# Processing Record 41 of Set 6 | helena
# Processing Record 42 of Set 6 | tornio
# Processing Record 43 of Set 6 | liverpool
# Processing Record 44 of Set 6 | batemans bay
# Processing Record 45 of Set 6 | nokaneng
# Processing Record 46 of Set 6 | kibre mengist
# Processing Record 47 of Set 6 | isugod
# Processing Record 48 of Set 6 | bengkulu
# Processing Record 49 of Set 6 | salinopolis
# Processing Record 50 of Set 6 | polyarnyy
# Processing Record 1 of Set 7 | presidente olegario
# Processing Record 2 of Set 7 | barvinkove
# Processing Record 3 of Set 7 | kapit
# Processing Record 4 of Set 7 | petukhovo
# Processing Record 5 of Set 7 | takoradi
# Processing Record 6 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 7 | saint-joseph
# Processing Record 8 of Set 7 | missoula
# Processing Record 9 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 7 | lamu
# Processing Record 11 of Set 7 | aioi
# Processing Record 12 of Set 7 | dubbo
# Processing Record 13 of Set 7 | zhangye
# Processing Record 14 of Set 7 | vestmannaeyjar
# Processing Record 15 of Set 7 | borba
# Processing Record 16 of Set 7 | bar harbor
# Processing Record 17 of Set 7 | barinas
# Processing Record 18 of Set 7 | gberia fotombu
# Processing Record 19 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 7 | muhos
# Processing Record 21 of Set 7 | sainte-anne-des-monts
# Processing Record 22 of Set 7 | grand-santi
# Processing Record 23 of Set 7 | malumfashi
# Processing Record 24 of Set 7 | burica
# City not found. Skipping...
# Processing Record 25 of Set 7 | general jose eduvigis diaz
# Processing Record 26 of Set 7 | makakilo city
# Processing Record 27 of Set 7 | vanimo
# Processing Record 28 of Set 7 | shingu
# Processing Record 29 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 7 | whitecourt
# Processing Record 31 of Set 7 | necochea
# Processing Record 32 of Set 7 | mehendiganj
# Processing Record 33 of Set 7 | korla
# Processing Record 34 of Set 7 | pilao arcado
# City not found. Skipping...
# Processing Record 35 of Set 7 | barreirinhas
# Processing Record 36 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 37 of Set 7 | san javier
# Processing Record 38 of Set 7 | pochutla
# Processing Record 39 of Set 7 | kilimatinde
# Processing Record 40 of Set 7 | klaksvik
# Processing Record 41 of Set 7 | trogir
# Processing Record 42 of Set 7 | ballina
# Processing Record 43 of Set 7 | cumpas
# Processing Record 44 of Set 7 | tommot
# Processing Record 45 of Set 7 | puyang
# Processing Record 46 of Set 7 | aitape
# Processing Record 47 of Set 7 | amapa
# Processing Record 48 of Set 7 | pingzhuang
# Processing Record 49 of Set 7 | te anau
# Processing Record 50 of Set 7 | nagato
# Processing Record 1 of Set 8 | broken arrow
# Processing Record 2 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 3 of Set 8 | ifanadiana
# Processing Record 4 of Set 8 | praia da vitoria
# Processing Record 5 of Set 8 | bud
# Processing Record 6 of Set 8 | cayenne
# Processing Record 7 of Set 8 | vila
# Processing Record 8 of Set 8 | hailar
# Processing Record 9 of Set 8 | bunbury
# Processing Record 10 of Set 8 | sao domingos
# Processing Record 11 of Set 8 | besikduzu
# Processing Record 12 of Set 8 | aktas
# Processing Record 13 of Set 8 | la macarena
# Processing Record 14 of Set 8 | warmbad
# Processing Record 15 of Set 8 | jatara
# Processing Record 16 of Set 8 | akureyri
# Processing Record 17 of Set 8 | lekoni
# Processing Record 18 of Set 8 | zhigansk
# Processing Record 19 of Set 8 | aklavik
# Processing Record 20 of Set 8 | enshi
# Processing Record 21 of Set 8 | kismayo
# Processing Record 22 of Set 8 | isangel
# Processing Record 23 of Set 8 | qiryat shemona
# Processing Record 24 of Set 8 | saint anthony
# Processing Record 25 of Set 8 | aberfeldy
# Processing Record 26 of Set 8 | kondinskoye
# Processing Record 27 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 28 of Set 8 | tsumeb
# Processing Record 29 of Set 8 | buta
# Processing Record 30 of Set 8 | bambous virieux
# Processing Record 31 of Set 8 | prince rupert
# Processing Record 32 of Set 8 | obihiro
# Processing Record 33 of Set 8 | bisira
# Processing Record 34 of Set 8 | viedma
# Processing Record 35 of Set 8 | yuzhne
# Processing Record 36 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 38 of Set 8 | hovd
# Processing Record 39 of Set 8 | boyuibe
# Processing Record 40 of Set 8 | susangerd
# Processing Record 41 of Set 8 | kamenka
# Processing Record 42 of Set 8 | peniche
# Processing Record 43 of Set 8 | sabang
# Processing Record 44 of Set 8 | papillion
# Processing Record 45 of Set 8 | rosarito
# Processing Record 46 of Set 8 | saint albans
# Processing Record 47 of Set 8 | lingao
# Processing Record 48 of Set 8 | north platte
# Processing Record 49 of Set 8 | honiara
# Processing Record 50 of Set 8 | teya
# Processing Record 1 of Set 9 | chicama
# Processing Record 2 of Set 9 | kahului
# Processing Record 3 of Set 9 | la palma
# Processing Record 4 of Set 9 | sakata
# Processing Record 5 of Set 9 | dharur
# Processing Record 6 of Set 9 | strathpeffer
# Processing Record 7 of Set 9 | lasa
# Processing Record 8 of Set 9 | hirara
# Processing Record 9 of Set 9 | mount gambier
# Processing Record 10 of Set 9 | wanning
# Processing Record 11 of Set 9 | payson
# Processing Record 12 of Set 9 | haines junction
# Processing Record 13 of Set 9 | brae
# Processing Record 14 of Set 9 | henties bay
# Processing Record 15 of Set 9 | college
# Processing Record 16 of Set 9 | canora
# Processing Record 17 of Set 9 | lorengau
# Processing Record 18 of Set 9 | boden
# Processing Record 19 of Set 9 | bonthe
# Processing Record 20 of Set 9 | beian
# Processing Record 21 of Set 9 | porosozero
# Processing Record 22 of Set 9 | kavieng
# Processing Record 23 of Set 9 | gravdal
# Processing Record 24 of Set 9 | seminole
# Processing Record 25 of Set 9 | mao
# Processing Record 26 of Set 9 | tolmachevo
# Processing Record 27 of Set 9 | san vicente
# Processing Record 28 of Set 9 | ketchikan
# Processing Record 29 of Set 9 | havoysund
# Processing Record 30 of Set 9 | senneterre
# Processing Record 31 of Set 9 | ambilobe
# Processing Record 32 of Set 9 | seidu
# Processing Record 33 of Set 9 | oranjemund
# Processing Record 34 of Set 9 | kidal
# Processing Record 35 of Set 9 | wuan
# Processing Record 36 of Set 9 | montlucon
# Processing Record 37 of Set 9 | salekhard
# Processing Record 38 of Set 9 | catia la mar
# Processing Record 39 of Set 9 | ares
# Processing Record 40 of Set 9 | bubaque
# Processing Record 41 of Set 9 | shiggaon
# Processing Record 42 of Set 9 | clarence town
# Processing Record 43 of Set 9 | saharanpur
# Processing Record 44 of Set 9 | kargapolye
# City not found. Skipping...
# Processing Record 45 of Set 9 | mathbaria
# Processing Record 46 of Set 9 | yar-sale
# Processing Record 47 of Set 9 | key largo
# Processing Record 48 of Set 9 | nisia floresta
# Processing Record 49 of Set 9 | akhisar
# Processing Record 50 of Set 9 | derzhavinsk
# Processing Record 1 of Set 10 | camara de lobos
# Processing Record 2 of Set 10 | saint-augustin
# Processing Record 3 of Set 10 | escuinapa
# Processing Record 4 of Set 10 | nelson bay
# Processing Record 5 of Set 10 | kumano
# Processing Record 6 of Set 10 | molteno
# Processing Record 7 of Set 10 | iquique
# Processing Record 8 of Set 10 | pemangkat
# Processing Record 9 of Set 10 | jomalig
# City not found. Skipping...
# Processing Record 10 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 11 of Set 10 | pokhara
# Processing Record 12 of Set 10 | hamilton
# Processing Record 13 of Set 10 | porto empedocle
# Processing Record 14 of Set 10 | severo-kurilsk
# Processing Record 15 of Set 10 | atoyac
# Processing Record 16 of Set 10 | chumikan
# Processing Record 17 of Set 10 | caraballeda
# Processing Record 18 of Set 10 | priladozhskiy
# Processing Record 19 of Set 10 | labuhan
# Processing Record 20 of Set 10 | andenes
# Processing Record 21 of Set 10 | astana
# Processing Record 22 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 10 | port hedland
# Processing Record 24 of Set 10 | magaria
# Processing Record 25 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 10 | meulaboh
# Processing Record 27 of Set 10 | salvador
# Processing Record 28 of Set 10 | cidreira
# Processing Record 29 of Set 10 | sault sainte marie
# Processing Record 30 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 10 | puerto ayacucho
# Processing Record 32 of Set 10 | marrakesh
# Processing Record 33 of Set 10 | voh
# Processing Record 34 of Set 10 | mayumba
# Processing Record 35 of Set 10 | tilichiki
# Processing Record 36 of Set 10 | oksfjord
# Processing Record 37 of Set 10 | kuandian
# Processing Record 38 of Set 10 | waingapu
# Processing Record 39 of Set 10 | valparaiso
# Processing Record 40 of Set 10 | xining
# Processing Record 41 of Set 10 | kinna
# Processing Record 42 of Set 10 | puebloviejo
# Processing Record 43 of Set 10 | nizhnyaya omka
# Processing Record 44 of Set 10 | qui nhon
# Processing Record 45 of Set 10 | palmer
# Processing Record 46 of Set 10 | goderich
# Processing Record 47 of Set 10 | broome
# Processing Record 48 of Set 10 | tessalit
# Processing Record 49 of Set 10 | novyy svit
# Processing Record 50 of Set 10 | nhamunda
# Processing Record 1 of Set 11 | riyadh
# City not found. Skipping...
# Processing Record 2 of Set 11 | evensk
# City not found. Skipping...
# Processing Record 3 of Set 11 | vetapalem
# City not found. Skipping...
# Processing Record 4 of Set 11 | westport
# City not found. Skipping...
# Processing Record 5 of Set 11 | markova
# City not found. Skipping...
# Processing Record 6 of Set 11 | revelstoke
# City not found. Skipping...
# Processing Record 7 of Set 11 | edgewater
# City not found. Skipping...
# Processing Record 8 of Set 11 | tiarei
# City not found. Skipping...
# Processing Record 9 of Set 11 | poum
# City not found. Skipping...
# Processing Record 10 of Set 11 | salalah
# City not found. Skipping...
# Processing Record 11 of Set 11 | ishigaki
# City not found. Skipping...
# Processing Record 12 of Set 11 | saint-louis
# City not found. Skipping...
# Processing Record 13 of Set 11 | rajapalaiyam
# City not found. Skipping...
# Processing Record 14 of Set 11 | narsaq
# City not found. Skipping...
# Processing Record 15 of Set 11 | olafsvik
# Processing Record 16 of Set 11 | karratha
# Processing Record 17 of Set 11 | cavalcante
# Processing Record 18 of Set 11 | shimoda
# Processing Record 19 of Set 11 | alushta
# Processing Record 20 of Set 11 | opuwo
# Processing Record 21 of Set 11 | nea kallikratia
# Processing Record 22 of Set 11 | sambava
# Processing Record 23 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 11 | chirongui
# Processing Record 25 of Set 11 | naze
# Processing Record 26 of Set 11 | dvinskoy
# Processing Record 27 of Set 11 | bonfim
# Processing Record 28 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 29 of Set 11 | maniitsoq
# Processing Record 30 of Set 11 | kizukuri
# Processing Record 31 of Set 11 | inhambane
# Processing Record 32 of Set 11 | stornoway
# Processing Record 33 of Set 11 | turukhansk
# Processing Record 34 of Set 11 | ambulu
# Processing Record 35 of Set 11 | tarnow
# Processing Record 36 of Set 11 | pismo beach
# Processing Record 37 of Set 11 | mantiquil
# Processing Record 38 of Set 11 | severodvinsk
# Processing Record 39 of Set 11 | capiibary
# Processing Record 40 of Set 11 | sao joao da barra
# Processing Record 41 of Set 11 | aruppukkottai
# Processing Record 42 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 11 | port augusta
# Processing Record 44 of Set 11 | jinchang
# Processing Record 45 of Set 11 | tuatapere
# Processing Record 46 of Set 11 | ilulissat
# Processing Record 47 of Set 11 | kaohsiung
# Processing Record 48 of Set 11 | kieta
# Processing Record 49 of Set 11 | virginia beach
# Processing Record 50 of Set 11 | balykshi
# Processing Record 1 of Set 12 | muscat
# Processing Record 2 of Set 12 | alvaraes
# Processing Record 3 of Set 12 | lumberton
# Processing Record 4 of Set 12 | ola
# Processing Record 5 of Set 12 | laguna
# Processing Record 6 of Set 12 | rosetta
# Processing Record 7 of Set 12 | dukat
# Processing Record 8 of Set 12 | ryotsu
# Processing Record 9 of Set 12 | talnakh
# Processing Record 10 of Set 12 | manavalakurichi
# Processing Record 11 of Set 12 | nanakuli
# Processing Record 12 of Set 12 | cassilandia
# Processing Record 13 of Set 12 | lerwick
# Processing Record 14 of Set 12 | umm jarr
# City not found. Skipping...
# Processing Record 15 of Set 12 | locri
# Processing Record 16 of Set 12 | aqtobe
# Processing Record 17 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 18 of Set 12 | kloulklubed
# Processing Record 19 of Set 12 | kiruna
# Processing Record 20 of Set 12 | mitsamiouli
# Processing Record 21 of Set 12 | kasungu
# Processing Record 22 of Set 12 | ewa beach
# Processing Record 23 of Set 12 | roald
# Processing Record 24 of Set 12 | nybro
# Processing Record 25 of Set 12 | semey
# Processing Record 26 of Set 12 | udachnyy
# Processing Record 27 of Set 12 | along
# Processing Record 28 of Set 12 | verkhnyaya inta
# Processing Record 29 of Set 12 | konya
# Processing Record 30 of Set 12 | guanica
# Processing Record 31 of Set 12 | issoudun
# Processing Record 32 of Set 12 | zyryanka
# Processing Record 33 of Set 12 | tautira
# Processing Record 34 of Set 12 | havelock
# Processing Record 35 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 36 of Set 12 | tiznit
# Processing Record 37 of Set 12 | moroni
# Processing Record 38 of Set 12 | namtsy
# Processing Record 39 of Set 12 | matay
# Processing Record 40 of Set 12 | santa cecilia
# Processing Record 41 of Set 12 | kununurra
# Processing Record 42 of Set 12 | nahan
# Processing Record 43 of Set 12 | nalut
# Processing Record 44 of Set 12 | tairua
# Processing Record 45 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 46 of Set 12 | aksu
# Processing Record 47 of Set 12 | whitehorse
# Processing Record 48 of Set 12 | margate
# Processing Record 49 of Set 12 | antalaha
# Processing Record 50 of Set 12 | bobcaygeon
# Processing Record 1 of Set 13 | uvat
# Processing Record 2 of Set 13 | ginir
# Processing Record 3 of Set 13 | toora-khem
# Processing Record 4 of Set 13 | nador
# Processing Record 5 of Set 13 | kamaishi
# Processing Record 6 of Set 13 | abay
# Processing Record 7 of Set 13 | sibolga
# Processing Record 8 of Set 13 | santa fe
# Processing Record 9 of Set 13 | el astillero
# Processing Record 10 of Set 13 | porto nacional
# Processing Record 11 of Set 13 | alamogordo
# Processing Record 12 of Set 13 | sorland
# Processing Record 13 of Set 13 | nyagan
# Processing Record 14 of Set 13 | kazerun
# Processing Record 15 of Set 13 | ulaangom
# Processing Record 16 of Set 13 | palauig
# Processing Record 17 of Set 13 | obo
# Processing Record 18 of Set 13 | buala
# Processing Record 19 of Set 13 | cervo
# Processing Record 20 of Set 13 | brandon
# Processing Record 21 of Set 13 | vila do maio
# Processing Record 22 of Set 13 | saint-leu
# Processing Record 23 of Set 13 | touros
# Processing Record 24 of Set 13 | san ignacio
# Processing Record 25 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 26 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 27 of Set 13 | maykain
# City not found. Skipping...
# Processing Record 28 of Set 13 | aksarka
# Processing Record 29 of Set 13 | shenjiamen
# Processing Record 30 of Set 13 | jumla
# Processing Record 31 of Set 13 | bay roberts
# Processing Record 32 of Set 13 | nampula
# Processing Record 33 of Set 13 | mayo
# Processing Record 34 of Set 13 | krasnaya poyma
# Processing Record 35 of Set 13 | gat
# Processing Record 36 of Set 13 | burriana
# Processing Record 37 of Set 13 | coihaique
# Processing Record 38 of Set 13 | lucea
# Processing Record 39 of Set 13 | alta gracia
# Processing Record 40 of Set 13 | gazanjyk
# Processing Record 41 of Set 13 | comodoro rivadavia
# Processing Record 42 of Set 13 | urumqi
# Processing Record 43 of Set 13 | quimper
# Processing Record 44 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 13 | yarada
# Processing Record 46 of Set 13 | la ronge
# Processing Record 47 of Set 13 | olymskiy
# City not found. Skipping...
# Processing Record 48 of Set 13 | egvekinot
# Processing Record 49 of Set 13 | xai-xai
# Processing Record 50 of Set 13 | kutum
# Processing Record 1 of Set 14 | moranbah
# Processing Record 2 of Set 14 | qazanbulaq
# Processing Record 3 of Set 14 | xuddur
# Processing Record 4 of Set 14 | sargatskoye
# Processing Record 5 of Set 14 | vostok
# Processing Record 6 of Set 14 | bodden town
# Processing Record 7 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 14 | buzmeyin
# Processing Record 9 of Set 14 | bartica
# Processing Record 10 of Set 14 | otane
# Processing Record 11 of Set 14 | saint-denis
# Processing Record 12 of Set 14 | kendari
# Processing Record 13 of Set 14 | jacqueville
# Processing Record 14 of Set 14 | honolulu
# Processing Record 15 of Set 14 | pishva
# Processing Record 16 of Set 14 | rockport
# Processing Record 17 of Set 14 | ko samui
# Processing Record 18 of Set 14 | ottumwa
# Processing Record 19 of Set 14 | atherton
# Processing Record 20 of Set 14 | saint-michel-des-saints
# Processing Record 21 of Set 14 | springfield
# Processing Record 22 of Set 14 | mumford
# Processing Record 23 of Set 14 | san isidro
# Processing Record 24 of Set 14 | panguna
# Processing Record 25 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 14 | ostrovnoy
# Processing Record 27 of Set 14 | ulagan
# Processing Record 28 of Set 14 | wairoa
# Processing Record 29 of Set 14 | gistel
# Processing Record 30 of Set 14 | dudinka
# Processing Record 31 of Set 14 | mariental
# Processing Record 32 of Set 14 | san jeronimo
# Processing Record 33 of Set 14 | hami
# Processing Record 34 of Set 14 | suntar
# Processing Record 35 of Set 14 | porto novo
# Processing Record 36 of Set 14 | leningradskiy
# Processing Record 37 of Set 14 | mahibadhoo
# Processing Record 38 of Set 14 | riachao das neves
# Processing Record 39 of Set 14 | humaita
# Processing Record 40 of Set 14 | koslan
# Processing Record 41 of Set 14 | humberto de campos
# Processing Record 42 of Set 14 | nanortalik
# Processing Record 43 of Set 14 | kulhudhuffushi
# Processing Record 44 of Set 14 | ahuimanu
# Processing Record 45 of Set 14 | atyrau
# Processing Record 46 of Set 14 | the valley
# Processing Record 47 of Set 14 | baglung
# Processing Record 48 of Set 14 | flinders
# Processing Record 49 of Set 14 | fort nelson
# Processing Record 50 of Set 14 | miyang
# Processing Record 1 of Set 15 | puri
# Processing Record 2 of Set 15 | otautau
# Processing Record 3 of Set 15 | santa isabel do rio negro
# Processing Record 4 of Set 15 | biltine
# Processing Record 5 of Set 15 | balabac
# Processing Record 6 of Set 15 | lobito
# Processing Record 7 of Set 15 | raudeberg
# Processing Record 8 of Set 15 | gandorhun
# Processing Record 9 of Set 15 | pinsk
# Processing Record 10 of Set 15 | belmonte
# Processing Record 11 of Set 15 | warkworth
# Processing Record 12 of Set 15 | apatity
# Processing Record 13 of Set 15 | vila franca do campo
# Processing Record 14 of Set 15 | bayir
# Processing Record 15 of Set 15 | mascota
# Processing Record 16 of Set 15 | denpasar
# Processing Record 17 of Set 15 | viamao
# Processing Record 18 of Set 15 | shakawe
# Processing Record 19 of Set 15 | yamada
# Processing Record 20 of Set 15 | linchuan
# City not found. Skipping...
# Processing Record 21 of Set 15 | goundam
# Processing Record 22 of Set 15 | tabou
# Processing Record 23 of Set 15 | gazojak
# Processing Record 24 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 15 | ariquemes
# Processing Record 26 of Set 15 | kajaani
# Processing Record 27 of Set 15 | maldonado
# Processing Record 28 of Set 15 | totma
# Processing Record 29 of Set 15 | kuala terengganu
# Processing Record 30 of Set 15 | orcotuna
# Processing Record 31 of Set 15 | sampit
# Processing Record 32 of Set 15 | sitio novo do tocantins
# Processing Record 33 of Set 15 | kaa-khem
# Processing Record 34 of Set 15 | yulara
# Processing Record 35 of Set 15 | kibara
# Processing Record 36 of Set 15 | morehead
# Processing Record 37 of Set 15 | port-gentil
# Processing Record 38 of Set 15 | mnogovershinnyy
# Processing Record 39 of Set 15 | khani
# Processing Record 40 of Set 15 | eureka
# Processing Record 41 of Set 15 | warrensburg
# Processing Record 42 of Set 15 | balikpapan
# Processing Record 43 of Set 15 | meghraj
# Processing Record 44 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 45 of Set 15 | san policarpo
# Processing Record 46 of Set 15 | katobu
# Processing Record 47 of Set 15 | arinos
# Processing Record 48 of Set 15 | dhrangadhra
# Processing Record 49 of Set 15 | gamba
# Processing Record 50 of Set 15 | bougouni
# Processing Record 1 of Set 16 | amahai
# Processing Record 2 of Set 16 | parabel
# Processing Record 3 of Set 16 | catende
# Processing Record 4 of Set 16 | rawson
# Processing Record 5 of Set 16 | sakakah
# Processing Record 6 of Set 16 | kyaikto
# Processing Record 7 of Set 16 | lock haven
# Processing Record 8 of Set 16 | esmeraldas
# Processing Record 9 of Set 16 | asau
# Processing Record 10 of Set 16 | linjiang
# Processing Record 11 of Set 16 | casale monferrato
# Processing Record 12 of Set 16 | pangnirtung
# Processing Record 13 of Set 16 | marneuli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Akhalgori      GE  42.1260   44.4833     51.94        88         100
# 1  Bjornevatn      NO  69.6672   29.9847     25.14        80          75
# 2    Victoria      HK  22.2855  114.1577     82.45        89         100
# 3    Hermanus      ZA -34.4187   19.2345     59.81        83          41
# 4   Mahebourg      MU -20.4081   57.7000     73.26        73           7
#
#    Wind Speed Current Description
# 0        4.00     overcast clouds
# 1       12.66       broken clouds
# 2        8.99     overcast clouds
# 3        7.47    scattered clouds
# 4        9.55           clear sky

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
